# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sktime.detection.clasp import ClaSPSegmentation

df = pd.read_csv('../data/iot_telemetry_data.csv',
                 names=['ts','device','co','humidity','light',
                        'lpg','motion','smoke','temp'],
                 skiprows=1)
df['ts'] = pd.to_datetime(df['ts'].astype(float), unit='s')
df = df.sort_values(['device', 'ts'])
df['motion'] = df['motion'].astype(bool)
df['light'] = df['light'].astype(bool)

# %%
device_id = 'b8:27:eb:bf:9d:51'
device_df = df[df['device'] == device_id].copy()
device_df = device_df.set_index('ts')

# Use temperature as our target series
temp_series = device_df['temp']
print(temp_series.shape)
print(temp_series.head())
# Out:
# (187450,)
# ts
# 2020-07-12 00:01:38.073572874    22.6
# 2020-07-12 00:01:41.761234999    22.6
# 2020-07-12 00:01:45.448863506    22.6
# 2020-07-12 00:01:49.136686802    22.6
# 2020-07-12 00:01:52.798517942    22.6
# Name: temp, dtype: float64

# %%
! pip install numba
# Out:
# Requirement already satisfied: numba in c:\users\ronak\appdata\local\programs\python\python312\lib\site-packages (0.65.1)
# Requirement already satisfied: llvmlite<0.48,>=0.47.0dev0 in c:\users\ronak\appdata\local\programs\python\python312\lib\site-packages (from numba) (0.47.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\ronak\appdata\local\programs\python\python312\lib\site-packages (from numba) (2.0.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
clasp = ClaSPSegmentation(period_length=50, n_cps=5)
clasp.fit(temp_series)
change_points = clasp.predict(temp_series)
print("Detected change points:")
print(change_points)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 clasp = ClaSPSegmentation(period_length=50, n_cps=5)
#       2 clasp.fit(temp_series)
# ----> 3 change_points = clasp.predict(temp_series)
#       4 print("Detected change points:")
#       5 print(change_points)
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\detection\base\_base.py:244, in BaseDetector.predict(self, X)
#     240 self.check_is_fitted()
#     242 X_inner = self._check_X(X)
# --> 244 y = self._predict(X=X_inner)
#     246 # deal with legacy return format with intervals in index
#     247 y = self._coerce_to_df(y, columns=["ilocs"])
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\detection\clasp.py:274, in ClaSPSegmentation._predict(self, X)
#     261 def _predict(self, X):
#     262     """Create annotations on test/deployment data.
#     263
#     264     Parameters
#    (...)    272         Change points in sequence X.
#     273     """
# --> 274     self.found_cps, self.profiles, self.scores = self._run_clasp(X)
#     275     return pd.Series(self.found_cps)
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\detection\clasp.py:335, in ClaSPSegmentation._run_clasp(self, X)
#     329     X = X.to_numpy()
#     331 clasp_transformer = ClaSPTransformer(
#     332     window_length=self.period_length, exclusion_radius=self.exclusion_radius
#     333 ).fit(X)
# --> 335 self.found_cps, self.profiles, self.scores = _segmentation(
#     336     X,
#     337     clasp_transformer,
#     338     n_change_points=self.n_cps,
#     339     exclusion_radius=self.exclusion_radius,
#     340 )
#     342 return self.found_cps, self.profiles, self.scores
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\detection\clasp.py:120, in _segmentation(X, clasp, n_change_points, exclusion_radius)
#     117 queue = PriorityQueue()
#     119 # compute global clasp
# --> 120 profile = clasp.transform(X)
#     121 queue.put(
#     122     (
#     123         -np.max(profile),
#     124         [np.arange(X.shape[0]).tolist(), np.argmax(profile), profile],
#     125     )
#     126 )
#     128 profiles = []
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\transformations\base.py:633, in BaseTransformer.transform(self, X, y)
#     631 # if no vectorization needed, we call _transform directly
#     632 if not vectorization_needed:
# --> 633     Xt = self._transform(X=X_inner, y=y_inner)
#     634 else:
#     635     # otherwise we call the vectorized version of predict
#     636     Xt = self._vectorize("transform", X=X_inner, y=y_inner)
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\transformations\series\clasp.py:112, in ClaSPTransformer._transform(self, X, y)
#     109 scoring_metric_call = self._check_scoring_metric(self.scoring_metric)
#     111 X = X.flatten()
# --> 112 Xt, _ = clasp(
#     113     X,
#     114     self.window_length,
#     115     score=scoring_metric_call,
#     116     exclusion_radius=self.exclusion_radius,
#     117 )
#     119 return Xt
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\transformations\series\_clasp_numba.py:334, in clasp(X, m, k_neighbours, score, interpolate, exclusion_radius)
#     331 n_timepoints = knn_mask.shape[1]
#     332 exclusion_radius = np.int64(n_timepoints * exclusion_radius)
# --> 334 profile = _calc_profile(m, knn_mask, score, exclusion_radius)
#     336 if interpolate is True:
#     337     profile = pd.Series(profile).interpolate(limit_direction="both").to_numpy()
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:376, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     374 return_val = None
#     375 try:
# --> 376     return_val = self.compile(tuple(argtypes))
#     377 except errors.ForceLiteralArg as e:
#     378     # Received request for compiler re-entry with the list of arguments
#     379     # indicated by e.requested_args.
#     380     # First, check if any of these args are already Literal-ized
#     381     already_lit_pos = [i for i in e.requested_args
#     382                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:908, in Dispatcher.compile(self, sig)
#     906 with ev.trigger_event("numba:compile", data=ev_details):
#     907     try:
# --> 908         cres = self._compiler.compile(args, return_type)
#     909     except errors.ForceLiteralArg as e:
#     910         def folded(args, kws):
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:80, in _FunctionCompiler.compile(self, args, return_type)
#      79 def compile(self, args, return_type):
# ---> 80     status, retval = self._compile_cached(args, return_type)
#      81     if status:
#      82         return retval
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:94, in _FunctionCompiler._compile_cached(self, args, return_type)
#      91     pass
#      93 try:
# ---> 94     retval = self._compile_core(args, return_type)
#      95 except errors.TypingError as e:
#      96     self._failed_cache[key] = e
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\dispatcher.py:107, in _FunctionCompiler._compile_core(self, args, return_type)
#     104 flags = self._customize_flags(flags)
#     106 impl = self._get_implementation(args, {})
# --> 107 cres = compiler.compile_extra(self.targetdescr.typing_context,
#     108                               self.targetdescr.target_context,
#     109                               impl,
#     110                               args=args, return_type=return_type,
#     111                               flags=flags, locals=self.locals,
#     112                               pipeline_class=self.pipeline_class)
#     113 # Check typing error if object mode is used
#     114 if cres.typing_error is not None and not flags.enable_pyobject:
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:737, in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library, pipeline_class)
#     713 def compile_extra(typingctx, targetctx, func, args, return_type, flags,
#     714                   locals, library=None, pipeline_class=Compiler):
#     715     """Compiler entry point
#     716
#     717     Parameter
#    (...)    735         compiler pipeline
#     736     """
# --> 737     pipeline = pipeline_class(typingctx, targetctx, library,
#     738                               args, return_type, flags, locals)
#     739     return pipeline.compile_extra(func)
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\compiler.py:395, in CompilerBase.__init__(self, typingctx, targetctx, library, args, return_type, flags, locals)
#     391 def __init__(self, typingctx, targetctx, library, args, return_type, flags,
#     392              locals):
#     393     # Make sure the environment is reloaded
#     394     config.reload_config()
# --> 395     typingctx.refresh()
#     396     targetctx.refresh()
#     398     self.state = StateDict()
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\context.py:239, in BaseContext.refresh(self)
#     237 self.load_additional_registries()
#     238 # Some extensions may have augmented the builtin registry
# --> 239 self._load_builtins()
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\context.py:484, in BaseContext._load_builtins(self)
#     482 def _load_builtins(self):
#     483     # Initialize declarations
# --> 484     from numba.core.typing import builtins, arraydecl, npdatetime  # noqa: F401, E501
#     485     from numba.core.typing import ctypes_utils, bufproto           # noqa: F401, E501
#     486     from numba.core.unsafe import eh                    # noqa: F401
#
# File c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\numba\core\typing\npdatetime.py:256
#     251             return
#     252         return signature(types.boolean, left, right)
#     255 @infer_global(operator.eq)
# --> 256 class DatetimeCmpEq(DatetimeCmpOp):
#     257     key = operator.eq
#     259 @infer_global(operator.ne)
#     260 class DatetimeCmpNe(DatetimeCmpOp):
#
# File <frozen abc>:105, in __new__(mcls, name, bases, namespace, **kwargs)
#
# KeyboardInterrupt:

# %%
# Use only first 5000 points for demonstration
temp_series_small = temp_series.iloc[:5000]

clasp = ClaSPSegmentation(period_length=50, n_cps=5)
clasp.fit(temp_series_small)
change_points = clasp.predict(temp_series_small)
print("Detected change points:")
print(change_points)
# Out:
# c:\Users\ronak\AppData\Local\Programs\Python\Python312\Lib\site-packages\sktime\transformations\series\_clasp_numba.py:52: RuntimeWarning: invalid value encountered in sqrt
#   movstd = np.sqrt(segSumSq / m - (segSum / m) ** 2)
# Detected change points:
#    ilocs
# 0   4526
# 1    923
# 2   1208
# 3   1930
